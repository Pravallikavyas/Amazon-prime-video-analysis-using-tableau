# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikavyas/Amazon-prime-video-analysis-using-tableau/blob/main/amazon_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/amazon_prime_titles.csv")

# %%
df
# Out:
#      show_id     type                           title  \
# 0         s1    Movie             The Grand Seduction
# 1         s2    Movie            Take Care Good Night
# 2         s3    Movie            Secrets of Deception
# 3         s4    Movie              Pink: Staying True
# 4         s5    Movie                   Monster Maker
# ...      ...      ...                             ...
# 5008   s5009  TV Show                           Solos
# 5009   s5010    Movie                          Shark!
# 5010   s5011    Movie                 Romance Analyst
# 5011   s5012    Movie                        Penelope
# 5012   s5013    Movie  NWA & Eazy-E: Kings of Compton
#
#                        director  \
# 0                  Don McKellar
# 1                  Girish Joshi
# 2                   Josh Webber
# 3                Sonia Anderson
# 4                  Giles Foster
# ...                         ...
# 5008                        NaN
# 5009                     Majaja
# ...

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df.tail()
# Out:
#      show_id     type                           title  \
# 5008   s5009  TV Show                           Solos
# 5009   s5010    Movie                          Shark!
# 5010   s5011    Movie                 Romance Analyst
# 5011   s5012    Movie                        Penelope
# 5012   s5013    Movie  NWA & Eazy-E: Kings of Compton
#
#                        director  \
# 5008                        NaN
# 5009                     Majaja
# 5010             Rachel Wortell
# 5011               Agustin Adba
# 5012  Mike Corbera, Andre Relis
#
#                                                    cast        country  \
# 5008          Uzo Aduba, Nicole Beharie, Morgan Freeman  United States
# 5009                                                NaN            NaN
# 5010  Lily Meyer, Peter Vack, Eleanore Pienta, Jeff ...            NaN
# 5011       Cumelen Sanz, Juan Barberini, Sergio Pangaro            NaN
# 5012  Chris Oliver, Ice Cube, Rasheed Stephens, Tyle...            NaN
#
# ...

# %%
df.shape
# Out:
# (5013, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1498
# cast             832
# country         4577
# date_added      4979
# release_year       0
# rating           316
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df["director"]=df["director"].replace(np.nan,"unknown")

# %%
df["cast"]=df["cast"].replace(np.nan,"unknown")

# %%
df["country"]=df["country"].fillna(df["country"].mode()[0])

# %%
df["rating"] = df["rating"].fillna(df["rating"].mode()[0])

# %%
df['date_added']=df['date_added'].ffill()

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
df['month_added']=df['date_added'].dt.month

# %%
df['year_added']=df['date_added'].dt.year

# %%
df
# Out:
#      show_id     type                           title  \
# 0         s1    Movie             The Grand Seduction
# 1         s2    Movie            Take Care Good Night
# 2         s3    Movie            Secrets of Deception
# 3         s4    Movie              Pink: Staying True
# 4         s5    Movie                   Monster Maker
# ...      ...      ...                             ...
# 5008   s5009  TV Show                           Solos
# 5009   s5010    Movie                          Shark!
# 5010   s5011    Movie                 Romance Analyst
# 5011   s5012    Movie                        Penelope
# 5012   s5013    Movie  NWA & Eazy-E: Kings of Compton
#
#                        director  \
# 0                  Don McKellar
# 1                  Girish Joshi
# 2                   Josh Webber
# 3                Sonia Anderson
# 4                  Giles Foster
# ...                         ...
# 5008                    unknown
# 5009                     Majaja
# ...

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014    13+  113 min            Comedy, Drama
# 1 2021-03-30          2018    13+  110 min     Drama, International
# ...

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
filename="amazon_primevideos.xlsx"

# %%
df.to_excel(filename)
